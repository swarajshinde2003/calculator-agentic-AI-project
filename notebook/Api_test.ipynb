# %%
print("dfghjk")
# Out:
# dfghjk

# %%
import os
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-oss:120b",
    base_url="https://ollama.com/v1",
    api_key=os.getenv("OLLAMA_API_KEY"),
    temperature=0.2
)
llm.invoke("What is Car")
# Out:
# AIMessage(content='**Car (automobile)**  \n\nA **car**—short for *automobile*—is a self‑propelled road vehicle designed primarily to transport people (and sometimes cargo) on public highways and streets. It typically has four wheels, an internal combustion engine or electric motor, and a cabin that seats one to eight occupants.\n\n---\n\n### Core Characteristics\n| Feature | Typical Details |\n|---------|-----------------|\n| **Powertrain** | • **Internal‑combustion engine (ICE)** – gasoline, diesel, or alternative fuels (e.g., LPG, CNG).<br>• **Electric motor** – battery‑electric (BEV) or hybrid (HEV/PHEV). |\n| **Chassis & Body** | • Steel, aluminum, or composite frame.<br>• Body styles: sedan, hatchback, SUV, coupe, convertible, wagon, pickup, etc. |\n| **Control Systems** | • Steering wheel, pedals (accelerator, brake, clutch for manual), gear selector.<br>• Modern cars add drive‑by‑wire, electronic stability control, adaptive cruise control, etc. |\n| **Safety Equipment** | • Passive: airbags, crumple zones, seat‑belt pretensioners.<br>• Active: ABS, ESC, lane‑keep assist, automatic emergency braking. |\n| **Legal Requirements** | • Registration, license plates, insurance, driver’s license, compliance with emissions and safety standards. |\n\n---\n\n### Brief History (Milestones)\n\n| Era | Key Development |\n|-----|-----------------|\n| **Late 19th\u202fc** | Karl Benz’s 1885‑86 *Motorwagen* – first practical gasoline car. |\n| **1900‑1930** | Mass production (Ford Model\u202fT, 1908) → affordable personal transport. |\n| **1930‑1960** | Streamlined designs, introduction of V‑8 engines, first automatic transmissions. |\n| **1970‑1990** | Oil crises → focus on fuel efficiency; rise of front‑wheel drive and compact cars. |\n| **1990‑2000** | Electronic engine management, airbags become standard, early hybrids (Toyota Prius, 1997). |\n| **2000‑2020** | Advanced driver‑assist systems (ADAS), infotainment, rise of SUVs, rapid growth of electric vehicles (Tesla Roadster 2008, Model\u202fS 2012). |\n| **2020‑present** | Accelerated EV adoption, autonomous‑driving pilots, connectivity (5G, OTA updates), lightweight materials. |\n\n---\n\n### Main Sub‑Categories\n\n| Category | Typical Use‑Case | Example Models |\n|----------|----------------|----------------|\n| **Sedan / Saloon** | Family or business commuting | Toyota Camry, BMW 3‑Series |\n| **Hatchback** | Urban driving, cargo flexibility | Volkswagen Golf, Honda Civic Hatch |\n| **SUV / Crossover** | Higher ride height, off‑road capability, families | Ford Explorer, Toyota RAV4 |\n| **Coupe / Convertible** | Sporty styling, performance | BMW M4, Mazda MX‑5 |\n| **Pickup / Light Truck** | Cargo hauling, work sites | Ford F‑150, Chevrolet Silverado |\n| **Electric Vehicle (EV)** | Zero‑tailpipe emissions, low operating cost | Tesla Model\u202f3, Nissan Leaf |\n| **Hybrid / Plug‑in Hybrid (PHEV)** | Combines ICE efficiency with electric range | Toyota Prius, Volvo XC60 Recharge |\n\n---\n\n### How a Conventional (ICE) Car Works – Simplified Flow\n\n1. **Fuel Delivery** – Gasoline/diesel is pumped from the tank to the engine.  \n2. **Combustion** – Spark plug ignites the air‑fuel mixture in each cylinder, creating high‑pressure gases.  \n3. **Power Stroke** – Expanding gases push pistons down, turning the crankshaft.  \n4. **Transmission** – Crankshaft rotation is transferred through a gearbox (manual, automatic, CVT) to the drive wheels.  \n5. **Exhaust** – Burned gases exit via the exhaust system, passing through catalytic converters to reduce pollutants.  \n\n*Electric cars replace steps\u202f1‑4 with a high‑voltage battery and one or more electric motors; they have far fewer moving parts and no exhaust.*\n\n---\n\n### Current Trends & Future Outlook\n\n| Trend | What It Means for Cars |\n|-------|------------------------|\n| **Electrification** | Battery costs falling → >30\u202f% of new sales in many markets by 2030; many manufacturers pledging all‑EV line‑ups. |\n| **Auto ...
